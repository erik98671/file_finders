# %%
from pathlib import Path

# %%
for p in Path(r"H:/Timeline/2022").glob("**/*.ipynb"):
    print(p)
# Out:
# H:\Timeline\2022\20220116\HCA Quarterly Accumulator Audit\HCA Quarterly Accumulator Audit.ipynb
# H:\Timeline\2022\20220116\HCA Quarterly Accumulator Audit\.ipynb_checkpoints\HCA Quarterly Accumulator Audit-checkpoint.ipynb
# H:\Timeline\2022\20220116\SAIF Quarterly Reconciliation 4Q21\Quarterly Eligibility Reconciliation for SAIF.ipynb
# H:\Timeline\2022\20220116\SAIF Quarterly Reconciliation 4Q21\.ipynb_checkpoints\Quarterly Eligibility Reconciliation for SAIF-checkpoint.ipynb
# H:\Timeline\2022\20220116\SR-1001073 UMP Washington Health Alliance Data File Change\GEOID.ipynb
# H:\Timeline\2022\20220116\SR-1001073 UMP Washington Health Alliance Data File Change\Step 1 - Create address lists.ipynb
# H:\Timeline\2022\20220116\SR-1001073 UMP Washington Health Alliance Data File Change\Step 2 - Combine address results.ipynb
# H:\Timeline\2022\20220116\SR-1001073 UMP Washington Health Alliance Data File Change\.ipynb_checkpoints\GEOID-checkpoint.ipynb
# ...
